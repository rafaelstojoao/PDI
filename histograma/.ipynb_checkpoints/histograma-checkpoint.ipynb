# %%
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(19680801)

# example data
mu = 100  # mean of distribution
sigma = 15  # standard deviation of distribution
x = mu + sigma * np.random.randn(437)

num_bins = 50

fig, ax = plt.subplots()

# the histogram of the data
n, bins, patches = ax.hist(x, num_bins, density=True)

# add a 'best fit' line
y = ((1 / (np.sqrt(2 * np.pi) * sigma)) *
     np.exp(-0.5 * (1 / sigma * (bins - mu))**2))
ax.plot(bins, y, '--')
ax.set_xlabel('Smarts')
ax.set_ylabel('Probability density')
ax.set_title(r'Histogram of IQ: $\mu=100$, $\sigma=15$')

# Tweak spacing to prevent clipping of ylabel
fig.tight_layout()
plt.show()

# %%
dados = pd.read_csv('country_wise_latest.csv')
dados.head()
# Out:
#   Country/Region  Confirmed  Deaths  Recovered  Active  New cases  New deaths  \
# 0    Afghanistan      36263    1269      25198    9796        106          10
# 1        Albania       4880     144       2745    1991        117           6
# 2        Algeria      27973    1163      18837    7973        616           8
# 3        Andorra        907      52        803      52         10           0
# 4         Angola        950      41        242     667         18           1
#
#    New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 0             18                3.50                  69.49
# 1             63                2.95                  56.25
# 2            749                4.16                  67.34
# 3              0                5.73                  88.53
# 4              0                4.32                  25.47
#
#    Deaths / 100 Recovered  Confirmed last week  1 week change  \
# 0                    5.04                35526            737
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt


dados = pd.read_csv('pessoas.csv')

mu = np.mean(dados['Peso'])  # mean of distribution
sigma = np.std(dados['Peso'])  # standard deviation of distribution
x = dados['Peso']


num_divisores = 5

fig, ax = plt.subplots()


n, bins, patches = ax.hist(x, num_divisores, density=True)



ax.set_xlabel('Peso')
ax.set_ylabel('Qtde. relativa')
ax.set_title(r'Histograma')

plt.show()

# %% [markdown]
# # Histograma de cinza

# %%
# !pip3 install opencv-python

import cv2
import numpy as np
from matplotlib import pyplot as plt

img = cv2.imread('../cagecinza.png',0) #o que se conclui dessa imagem?
# img = cv2.imread('../homem.jpg',0)  # e dessa?


# plt.hist(img.ravel(),10,[0,256],color='grey')
plt.hist(img.ravel(),100,[0,256],color='grey')
# plt.hist(img.ravel(),256,[0,256],color='grey')
plt.show()

histograma = img.ravel()
histograma
# Out:
# array([125, 122, 119, ...,  86,  86,  85], dtype=uint8)

# %% [markdown]
# #  Combinação de histogramas (merge)

# %%
import matplotlib.pyplot as plt

from skimage import data
from skimage import exposure
from skimage.exposure import match_histograms
from skimage.io import imread


imagem1=cv2.imread('../cagecinza.png') #original
imagem2 = imread('../menina.png') #mais escura

resultado = match_histograms(imagem1, imagem2, multichannel=True)

fig, (ax1, ax2, ax3) = plt.subplots(nrows=1, ncols=3, figsize=(8, 3),
                                    sharex=True, sharey=True)
for aa in (ax1, ax2, ax3):
    aa.set_axis_off()

ax1.imshow(imagem1)
ax1.set_title('Imagem 1')
ax2.imshow(imagem2)
ax2.set_title('Imagem 2')
ax3.imshow(resultado)
ax3.set_title('Combinação')

plt.tight_layout()
plt.show()

# %% [markdown]
# # Histograma de cores (RGB)

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

img = cv2.imread('../pordosol.jpg', -1)

color = ('b','g','r')

for channel,col in enumerate(color):
    histr = cv2.calcHist([img],[channel],None,[256],[0,256])
    plt.plot(histr,color = col)
    plt.xlim([0,256])
    
    
plt.title('Histograma  de cores (RGB)')
# Out:
# Text(0.5, 1.0, 'Histograma  de cores (RGB)')

# %% [markdown]
# # Mesclagem de histograma de cores

# %%
fig, axes = plt.subplots(nrows=3, ncols=3, figsize=(8, 8))


for i, img in enumerate((image, reference, matched)):
    for c, c_color in enumerate(('red', 'green', 'blue')):
        img_hist, bins = exposure.histogram(img[..., c], source_range='dtype')
        axes[c, i].plot(bins, img_hist / img_hist.max())
        img_cdf, bins = exposure.cumulative_distribution(img[..., c])
        axes[c, i].plot(bins, img_cdf)
        axes[c, 0].set_ylabel(c_color)

axes[0, 0].set_title('Source')
axes[0, 1].set_title('Reference')
axes[0, 2].set_title('Matched')

plt.tight_layout()
plt.show()

# %% [markdown]
# # Algoritmo de equalização de histogramas

# %%
#Equalização


import matplotlib
import matplotlib.pyplot as plt
import numpy as np

from skimage import data, img_as_float
from skimage import exposure


matplotlib.rcParams['font.size'] = 8


def plot_img_and_hist(image, axes, bins=256):
    """Plot an image along with its histogram and cumulative histogram.

    """
    image = img_as_float(image)
    ax_img, ax_hist = axes
    ax_cdf = ax_hist.twinx()

    ax_img.imshow(image, cmap=plt.cm.gray)
    ax_img.set_axis_off()

    ax_hist.hist(image.ravel(), bins=bins, histtype='step', color='black')
    ax_hist.ticklabel_format(axis='y', style='scientific', scilimits=(0, 0))
    ax_hist.set_xlabel('Intensidade de pixels')
    ax_hist.set_xlim(0, 1)
    ax_hist.set_yticks([])

    # Display cumulative distribution
    img_cdf, bins = exposure.cumulative_distribution(image, bins)
    ax_cdf.plot(bins, img_cdf, 'r')
    ax_cdf.set_yticks([])

    return ax_img, ax_hist, ax_cdf


#Carregando a imagem
img = data.moon()

p2, p98 = np.percentile(img, (2, 98))
img_rescale = exposure.rescale_intensity(img, in_range=(p2, p98))

# Equalização
img_eq = exposure.equalize_hist(img)

# Equalização adaptativa
img_adapteq = exposure.equalize_adapthist(img, clip_limit=0.03)

# Resultados
fig = plt.figure(figsize=(8, 5))
axes = np.zeros((2, 4), dtype=np.object)
axes[0, 0] = fig.add_subplot(2, 4, 1)
for i in range(1, 4):
    axes[0, i] = fig.add_subplot(2, 4, 1+i, sharex=axes[0,0], sharey=axes[0,0])
for i in range(0, 4):
    axes[1, i] = fig.add_subplot(2, 4, 5+i)

ax_img, ax_hist, ax_cdf = plot_img_and_hist(img, axes[:, 0])
ax_img.set_title('Imagem de baixo contraste')

y_min, y_max = ax_hist.get_ylim()
ax_hist.set_ylabel('Número de pixels')
ax_hist.set_yticks(np.linspace(0, y_max, 5))

ax_img, ax_hist, ax_cdf = plot_img_and_hist(img_rescale, axes[:, 1])
ax_img.set_title('Contraste alongado')

ax_img, ax_hist, ax_cdf = plot_img_and_hist(img_eq, axes[:, 2])
ax_img.set_title('Equalização do Histograma')

ax_img, ax_hist, ax_cdf = plot_img_and_hist(img_adapteq, axes[:, 3])
ax_img.set_title('Equalização adaptativa')

fig.tight_layout()
plt.show()
