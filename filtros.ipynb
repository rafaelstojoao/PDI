# %%
from scipy import fftpack

import numpy as np
import imageio

from PIL import Image, ImageDraw

from skimage.io import imread

import matplotlib.pyplot as plt
import scipy.fftpack as fp

image1 = imageio.imread('pizza.jpg',as_gray=True)

#convert image to numpy array
image1_np=np.array(image1)
image1_np
# Out:
# array([[ 2.381,  2.669,  2.082, ..., 53.888, 53.888, 53.888],
#        [ 2.381,  2.669,  2.082, ..., 55.258, 55.258, 55.258],
#        [ 2.381,  2.381,  2.082, ..., 55.97 , 55.97 , 55.97 ],
#        ...,
#        [17.63 , 17.63 , 17.63 , ..., 22.642, 22.642, 22.642],
#        [19.228, 19.228, 19.228, ..., 22.642, 23.642, 23.642],
#        [19.228, 19.228, 19.228, ..., 23.642, 23.642, 23.642]],
#       dtype=float32)

# %%
import matplotlib.pyplot as plt
import numpy as np


img = plt.imread("pizza.jpg")/float(2**8)

plt.imshow(img)
plt.show()

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

img = cv2.imread('leao.jpg')


# # img[3][2]
# for pixel in img:
# #     print(pixel.shape)
# #     break
#     for cor in pixel:
# #             print("cor:",cor)
# #             break
#             for componente in cor:
# #                 print(componente)
#                 componente -=10
                
# #             break
            
# #     break
    
    
mascara = np.ones((5,5),np.float32)/50

# mascara

imgFiltrada = cv2.filter2D(img,-1,mascara)

# plt.subplot(121),plt.imshow(img),plt.title('Original')
plt.subplot(122),plt.imshow(imgFiltrada),plt.title('Médias')

plt.show()

# %%
img2 = cv2.imread('menina.png')

# plt.subplot(121),plt.imshow(img2),plt.title('Imagem Original com ruído')

imgfiltradamedia = cv2.medianBlur(img2,5)

plt.subplot(122),plt.imshow(imgfiltradamedia),plt.title('Médias')

plt.show()

# %%
imgfiltradamedia
# Out:
# array([[[42, 42, 42],
#         [44, 44, 44],
#         [70, 70, 70],
#         ...,
#         [16, 16, 16],
#         [62, 62, 62],
#         [74, 74, 74]],
#
#        [[44, 44, 44],
#         [50, 50, 50],
#         [70, 70, 70],
#         ...,
#         [36, 36, 36],
#         [61, 61, 61],
#         [65, 65, 65]],
#
#        [[47, 47, 47],
#         [54, 54, 54],
#         [69, 69, 69],
#         ...,
#         [54, 54, 54],
#         [61, 61, 61],
#         [65, 65, 65]],
#
#        ...,
#
#        [[73, 73, 73],
#         [73, 73, 73],
#         [79, 79, 79],
#         ...,
#         [69, 69, 69],
#         [69, 69, 69],
#         [69, 69, 69]],
#
#        [[73, 73, 73],
#         [73, 73, 73],
#         [73, 73, 73],
#         ...,
#         [69, 69, 69],
#         [70, 70, 70],
#         [70, 70, 70]],
#
#        [[73, 73, 73],
#         [68, 68, 68],
#         [68, 68, 68],
#         ...,
#         [69, 69, 69],
#         [70, 70, 70],
#         [70, 70, 70]]], dtype=uint8)

# %%
import numpy as np
import cv2

#read image
imgEntrada = cv2.imread('cagecinza.png')

#edge detection filter
mascara = np.array([[0.0, -1.0, 0.0], 
                   [-1.0,8.0, -1.0],
                   [0.0, -1.0, 0.0]])

mascara = mascara/(np.sum(mascara) if np.sum(mascara)!=0 else 1)

hpassimg = cv2.filter2D(imgEntrada,-1,mascara)

plt.subplot(),plt.imshow(imgEntrada),plt.title('Original')
# plt.subplot(),plt.imshow(hpassimg),plt.title('passa alta')



fig.show()
# Out:
# /home/rafael/.local/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
